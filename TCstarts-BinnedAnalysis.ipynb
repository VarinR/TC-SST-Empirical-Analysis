# %%
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import numpy as np
import pandas as pd
import scipy as scp
import netCDF4
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import os
import pickle
import matplotlib.gridspec as gridspec
import fastkde

# %% [markdown]
# <h2 style="font-size:28px; font-weight:bold;">Preparing Data</h2>

# %%
file_path1 = 'SSTs.nc'
file_path2 = 'TCs.nc'
  
                                  
ds1 = xr.open_dataset(file_path1)
ds2 = xr.open_dataset(file_path2)
# Out:
# /Users/varinradia/anaconda3/lib/python3.11/site-packages/xarray/coding/times.py:254: RuntimeWarning: invalid value encountered in cast
#   flat_num_dates_ns_int = (flat_num_dates * _NS_PER_TIME_DELTA[delta]).astype(

# %%
ds_grouped = ds1.groupby('time.year').mean(dim='time')                                   #Obtained Yearly Meaned Data
tropical_data = ds_grouped.sel(latitude=slice(23.5, -23.5), longitude=slice(0, 360))    #Extracted Data For the Tropics

# %%
with open("storms_by_year.pk", "rb") as fin:  
 storms = pickle.load(fin)

# %% [markdown]
# <h2 style="font-size:28px; font-weight:bold;">Exctracting lat and lon data for each storm that were sorted by year</h2>

# %%
# Initialize a dictionary to store storm information with latitudes and longitudes
storm_info = {}

# Iterate over the years in the storms dictionary
for year, storm_ids_year in storms.items():
    # Initialize a dictionary to store storm information for the current year
    storm_info_year = {}
    # Iterate over the storm IDs for the current year
    for storm_id in storm_ids_year:
        # Find the storm data for the current storm ID
        storm_data = ds2.sel(storm=storm_id)
        # Extract latitude and longitude values
        latitudes = storm_data['lat'].values
        longitudes = storm_data['lon'].values
        # Store latitude and longitude values in the storm_info_year dictionary
        storm_info_year[storm_id] = {'lat': latitudes, 'lon': longitudes}
    # Store storm information for the current year in the storm_info dictionary
    storm_info[year] = storm_info_year

# %% [markdown]
# <h2 style="font-size:28px; font-weight:bold;">Analyzing the Relationship Between SST and Tropical Cyclone Genesis Across 5°x5° grid Boxes</h2>

# %%
lat_edges = np.arange(-20, 21, 5)
lon_edges = np.arange(0, 360, 5)

result = {}  # Re-initializing the dictionary to store the results

# Iterating over each year in the tropical data
for year in tropical_data['year'].values:
    # Selecting SST data for the current year
    sst_data = tropical_data.sel(year=year)['sst']
    # Calculating the mean SST across all latitudes and longitudes for the year, skipping NaN values
    tropical_mean_sst = sst_data.mean(dim=['latitude', 'longitude'], skipna=True).item()

    # Iterating over each grid box defined by latitude and longitude edges
    for lat_start, lat_end in zip(lat_edges[:-1], lat_edges[1:]):
        for lon_start, lon_end in zip(lon_edges[:-1], lon_edges[1:]):
            # Selecting data for the current grid box
            grid_box_data = sst_data.sel(latitude=slice(lat_end, lat_start), longitude=slice(lon_start, lon_end))

            if grid_box_data.size > 0:
                # Calculating the mean SST for the current grid box, skipping NaN values
                grid_box_mean_sst = grid_box_data.mean(dim=['latitude', 'longitude'], skipna=True).item()

                # Calculating deltaSST
                deltaSST = grid_box_mean_sst - tropical_mean_sst

                if grid_box_mean_sst > tropical_mean_sst:
                    tc_starts = 0  # Initializing the counter for tropical cyclones starting in this grid box
                    if year in storm_info:
                        for storm_data in storm_info[year].values():
                            storm_lat = storm_data['lat'][0]  # Getting the starting latitude of the storm
                            storm_lon = storm_data['lon'][0]  # Getting the starting longitude of the storm
                            if lat_start <= storm_lat <= lat_end and lon_start <= (storm_lon + 360) % 360 <= lon_end:
                                tc_starts += 1

                    # Storing the results for the current year and grid box
                    if year not in result:
                        result[year] = []
                    result[year].append({
                        'gridbox': f'{lat_start}-{lat_end}, {lon_start}-{lon_end}',
                        'avg_sst': grid_box_mean_sst,
                        'deltaSST': deltaSST,  # Adding deltaSST to the results
                        'TCs_started': tc_starts,
                        'year': year
                    })
            else:
                print(f"Grid box {lat_start}-{lat_end}, {lon_start}-{lon_end} is empty.")

# %%
result
# Out:
# {1971: [{'gridbox': '-20--15, 25-30',
#    'avg_sst': 299.8190002441406,
#    'deltaSST': 0.30328369140625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 35-40',
#    'avg_sst': 299.73193359375,
#    'deltaSST': 0.216217041015625,
#    'TCs_started': 3,
#    'year': 1971},
#   {'gridbox': '-20--15, 40-45',
#    'avg_sst': 300.3172607421875,
#    'deltaSST': 0.801544189453125,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-20--15, 45-50',
#    'avg_sst': 299.6469421386719,
#    'deltaSST': 0.1312255859375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 110-115',
#    'avg_sst': 299.6444396972656,
#    'deltaSST': 0.12872314453125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 115-120',
#    'avg_sst': 300.438720703125,
#    'deltaSST': 0.923004150390625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 120-125',
#    'avg_sst': 300.80194091796875,
#    'deltaSST': 1.286224365234375,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-20--15, 125-130',
#    'avg_sst': 300.8620300292969,
#    'deltaSST': 1.3463134765625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 135-140',
#    'avg_sst': 300.5483703613281,
#    'deltaSST': 1.03265380859375,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-20--15, 140-145',
#    'avg_sst': 300.44061279296875,
#    'deltaSST': 0.924896240234375,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-20--15, 145-150',
#    'avg_sst': 299.8509216308594,
#    'deltaSST': 0.335205078125,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-20--15, 150-155',
#    'avg_sst': 299.9481201171875,
#    'deltaSST': 0.432403564453125,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-20--15, 155-160',
#    'avg_sst': 299.9866027832031,
#    'deltaSST': 0.47088623046875,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-20--15, 160-165',
#    'avg_sst': 299.99365234375,
#    'deltaSST': 0.477935791015625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 165-170',
#    'avg_sst': 300.4608459472656,
#    'deltaSST': 0.94512939453125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 170-175',
#    'avg_sst': 300.7765808105469,
#    'deltaSST': 1.2608642578125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 175-180',
#    'avg_sst': 300.8816223144531,
#    'deltaSST': 1.36590576171875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 180-185',
#    'avg_sst': 300.7239685058594,
#    'deltaSST': 1.208251953125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 185-190',
#    'avg_sst': 300.6520690917969,
#    'deltaSST': 1.1363525390625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 190-195',
#    'avg_sst': 300.5537414550781,
#    'deltaSST': 1.03802490234375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 195-200',
#    'avg_sst': 300.56329345703125,
#    'deltaSST': 1.047576904296875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 200-205',
#    'avg_sst': 300.4727478027344,
#    'deltaSST': 0.95703125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 205-210',
#    'avg_sst': 300.350830078125,
#    'deltaSST': 0.835113525390625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 210-215',
#    'avg_sst': 300.11285400390625,
#    'deltaSST': 0.597137451171875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 215-220',
#    'avg_sst': 300.0094299316406,
#    'deltaSST': 0.49371337890625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 220-225',
#    'avg_sst': 299.8235168457031,
#    'deltaSST': 0.30780029296875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-20--15, 320-325',
#    'avg_sst': 299.5549621582031,
#    'deltaSST': 0.03924560546875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 40-45',
#    'avg_sst': 300.5045166015625,
#    'deltaSST': 0.988800048828125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 45-50',
#    'avg_sst': 300.4193115234375,
#    'deltaSST': 0.903594970703125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 50-55',
#    'avg_sst': 299.9098205566406,
#    'deltaSST': 0.39410400390625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 55-60',
#    'avg_sst': 299.9491882324219,
#    'deltaSST': 0.4334716796875,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-15--10, 60-65',
#    'avg_sst': 299.9788818359375,
#    'deltaSST': 0.463165283203125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 65-70',
#    'avg_sst': 299.9478759765625,
#    'deltaSST': 0.432159423828125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 70-75',
#    'avg_sst': 299.93707275390625,
#    'deltaSST': 0.421356201171875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 75-80',
#    'avg_sst': 300.1315612792969,
#    'deltaSST': 0.6158447265625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 80-85',
#    'avg_sst': 300.1038818359375,
#    'deltaSST': 0.588165283203125,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-15--10, 85-90',
#    'avg_sst': 300.1910095214844,
#    'deltaSST': 0.67529296875,
#    'TCs_started': 3,
#    'year': 1971},
#   {'gridbox': '-15--10, 90-95',
#    'avg_sst': 300.23333740234375,
#    'deltaSST': 0.717620849609375,
#    'TCs_started': 5,
#    'year': 1971},
#   {'gridbox': '-15--10, 95-100',
#    'avg_sst': 300.3403625488281,
#    'deltaSST': 0.82464599609375,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-15--10, 100-105',
#    'avg_sst': 300.2998962402344,
#    'deltaSST': 0.7841796875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 105-110',
#    'avg_sst': 300.4007263183594,
#    'deltaSST': 0.885009765625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 110-115',
#    'avg_sst': 300.6520080566406,
#    'deltaSST': 1.13629150390625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 115-120',
#    'avg_sst': 301.12542724609375,
#    'deltaSST': 1.609710693359375,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-15--10, 120-125',
#    'avg_sst': 301.53363037109375,
#    'deltaSST': 2.017913818359375,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-15--10, 125-130',
#    'avg_sst': 301.6036376953125,
#    'deltaSST': 2.087921142578125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 130-135',
#    'avg_sst': 301.5279235839844,
#    'deltaSST': 2.01220703125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 135-140',
#    'avg_sst': 301.12066650390625,
#    'deltaSST': 1.604949951171875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 140-145',
#    'avg_sst': 300.850341796875,
#    'deltaSST': 1.334625244140625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 145-150',
#    'avg_sst': 300.80035400390625,
#    'deltaSST': 1.284637451171875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 150-155',
#    'avg_sst': 301.23846435546875,
#    'deltaSST': 1.722747802734375,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-15--10, 155-160',
#    'avg_sst': 301.556640625,
#    'deltaSST': 2.040924072265625,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-15--10, 160-165',
#    'avg_sst': 301.7742004394531,
#    'deltaSST': 2.25848388671875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 165-170',
#    'avg_sst': 301.948486328125,
#    'deltaSST': 2.432769775390625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 170-175',
#    'avg_sst': 302.09075927734375,
#    'deltaSST': 2.575042724609375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 175-180',
#    'avg_sst': 302.0199890136719,
#    'deltaSST': 2.5042724609375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 180-185',
#    'avg_sst': 301.9190368652344,
#    'deltaSST': 2.4033203125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 185-190',
#    'avg_sst': 301.7132873535156,
#    'deltaSST': 2.19757080078125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 190-195',
#    'avg_sst': 301.60015869140625,
#    'deltaSST': 2.084442138671875,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-15--10, 195-200',
#    'avg_sst': 301.5496520996094,
#    'deltaSST': 2.033935546875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 200-205',
#    'avg_sst': 301.3702087402344,
#    'deltaSST': 1.8544921875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 205-210',
#    'avg_sst': 301.1498718261719,
#    'deltaSST': 1.6341552734375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 210-215',
#    'avg_sst': 300.7985534667969,
#    'deltaSST': 1.2828369140625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 215-220',
#    'avg_sst': 300.47442626953125,
#    'deltaSST': 0.958709716796875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 220-225',
#    'avg_sst': 300.0561828613281,
#    'deltaSST': 0.54046630859375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 225-230',
#    'avg_sst': 299.6274108886719,
#    'deltaSST': 0.1116943359375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 320-325',
#    'avg_sst': 300.2022705078125,
#    'deltaSST': 0.686553955078125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-15--10, 325-330',
#    'avg_sst': 299.9992980957031,
#    'deltaSST': 0.48358154296875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 25-30',
#    'avg_sst': 299.5813903808594,
#    'deltaSST': 0.065673828125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 35-40',
#    'avg_sst': 300.3359375,
#    'deltaSST': 0.820220947265625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 40-45',
#    'avg_sst': 300.57958984375,
#    'deltaSST': 1.063873291015625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 45-50',
#    'avg_sst': 300.4709167480469,
#    'deltaSST': 0.9552001953125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 50-55',
#    'avg_sst': 300.55126953125,
#    'deltaSST': 1.035552978515625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 55-60',
#    'avg_sst': 300.5531311035156,
#    'deltaSST': 1.03741455078125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 60-65',
#    'avg_sst': 300.80804443359375,
#    'deltaSST': 1.292327880859375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 65-70',
#    'avg_sst': 300.9029235839844,
#    'deltaSST': 1.38720703125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 70-75',
#    'avg_sst': 300.77197265625,
#    'deltaSST': 1.256256103515625,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-10--5, 75-80',
#    'avg_sst': 300.993408203125,
#    'deltaSST': 1.477691650390625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 80-85',
#    'avg_sst': 301.0530090332031,
#    'deltaSST': 1.53729248046875,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-10--5, 85-90',
#    'avg_sst': 301.02593994140625,
#    'deltaSST': 1.510223388671875,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-10--5, 90-95',
#    'avg_sst': 300.9291076660156,
#    'deltaSST': 1.41339111328125,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-10--5, 95-100',
#    'avg_sst': 300.9649658203125,
#    'deltaSST': 1.449249267578125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 100-105',
#    'avg_sst': 301.06591796875,
#    'deltaSST': 1.550201416015625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 105-110',
#    'avg_sst': 301.05633544921875,
#    'deltaSST': 1.540618896484375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 110-115',
#    'avg_sst': 301.163818359375,
#    'deltaSST': 1.648101806640625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 115-120',
#    'avg_sst': 301.30499267578125,
#    'deltaSST': 1.789276123046875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 120-125',
#    'avg_sst': 301.2699890136719,
#    'deltaSST': 1.7542724609375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 125-130',
#    'avg_sst': 301.3077087402344,
#    'deltaSST': 1.7919921875,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-10--5, 130-135',
#    'avg_sst': 301.21234130859375,
#    'deltaSST': 1.696624755859375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 135-140',
#    'avg_sst': 301.2225341796875,
#    'deltaSST': 1.706817626953125,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-10--5, 140-145',
#    'avg_sst': 301.0552673339844,
#    'deltaSST': 1.53955078125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 145-150',
#    'avg_sst': 301.76776123046875,
#    'deltaSST': 2.252044677734375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 150-155',
#    'avg_sst': 302.2188415527344,
#    'deltaSST': 2.703125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 155-160',
#    'avg_sst': 302.47308349609375,
#    'deltaSST': 2.957366943359375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 160-165',
#    'avg_sst': 302.45013427734375,
#    'deltaSST': 2.934417724609375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 165-170',
#    'avg_sst': 302.4311218261719,
#    'deltaSST': 2.9154052734375,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '-10--5, 170-175',
#    'avg_sst': 302.323486328125,
#    'deltaSST': 2.807769775390625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 175-180',
#    'avg_sst': 302.1133117675781,
#    'deltaSST': 2.59759521484375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 180-185',
#    'avg_sst': 301.9055480957031,
#    'deltaSST': 2.38983154296875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 185-190',
#    'avg_sst': 301.72198486328125,
#    'deltaSST': 2.206268310546875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 190-195',
#    'avg_sst': 301.4735412597656,
#    'deltaSST': 1.95782470703125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 195-200',
#    'avg_sst': 301.2698669433594,
#    'deltaSST': 1.754150390625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 200-205',
#    'avg_sst': 301.0306701660156,
#    'deltaSST': 1.51495361328125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 205-210',
#    'avg_sst': 300.77435302734375,
#    'deltaSST': 1.258636474609375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 210-215',
#    'avg_sst': 300.4408874511719,
#    'deltaSST': 0.9251708984375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 215-220',
#    'avg_sst': 300.16717529296875,
#    'deltaSST': 0.651458740234375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 220-225',
#    'avg_sst': 299.8565979003906,
#    'deltaSST': 0.34088134765625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 320-325',
#    'avg_sst': 300.4617614746094,
#    'deltaSST': 0.946044921875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 325-330',
#    'avg_sst': 300.4308166503906,
#    'deltaSST': 0.91510009765625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 330-335',
#    'avg_sst': 300.0202331542969,
#    'deltaSST': 0.5045166015625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-10--5, 335-340',
#    'avg_sst': 299.6300354003906,
#    'deltaSST': 0.11431884765625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 15-20',
#    'avg_sst': 302.4466857910156,
#    'deltaSST': 2.93096923828125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 35-40',
#    'avg_sst': 299.9508361816406,
#    'deltaSST': 0.43511962890625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 40-45',
#    'avg_sst': 300.3558044433594,
#    'deltaSST': 0.840087890625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 45-50',
#    'avg_sst': 300.42010498046875,
#    'deltaSST': 0.904388427734375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 50-55',
#    'avg_sst': 300.9269104003906,
#    'deltaSST': 1.41119384765625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 55-60',
#    'avg_sst': 301.2294616699219,
#    'deltaSST': 1.7137451171875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 60-65',
#    'avg_sst': 301.44390869140625,
#    'deltaSST': 1.928192138671875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 65-70',
#    'avg_sst': 301.59814453125,
#    'deltaSST': 2.082427978515625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 70-75',
#    'avg_sst': 301.680419921875,
#    'deltaSST': 2.164703369140625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 75-80',
#    'avg_sst': 301.6133117675781,
#    'deltaSST': 2.09759521484375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 80-85',
#    'avg_sst': 301.694580078125,
#    'deltaSST': 2.178863525390625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 85-90',
#    'avg_sst': 301.7589416503906,
#    'deltaSST': 2.24322509765625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 90-95',
#    'avg_sst': 301.8186340332031,
#    'deltaSST': 2.30291748046875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 95-100',
#    'avg_sst': 301.9092712402344,
#    'deltaSST': 2.3935546875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 100-105',
#    'avg_sst': 301.7862854003906,
#    'deltaSST': 2.27056884765625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 105-110',
#    'avg_sst': 301.6417541503906,
#    'deltaSST': 2.12603759765625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 110-115',
#    'avg_sst': 301.56884765625,
#    'deltaSST': 2.053131103515625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 115-120',
#    'avg_sst': 301.7675476074219,
#    'deltaSST': 2.2518310546875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 120-125',
#    'avg_sst': 301.70001220703125,
#    'deltaSST': 2.184295654296875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 125-130',
#    'avg_sst': 301.6453552246094,
#    'deltaSST': 2.129638671875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 130-135',
#    'avg_sst': 301.79339599609375,
#    'deltaSST': 2.277679443359375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 135-140',
#    'avg_sst': 302.366455078125,
#    'deltaSST': 2.850738525390625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 140-145',
#    'avg_sst': 302.33917236328125,
#    'deltaSST': 2.823455810546875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 145-150',
#    'avg_sst': 302.3638916015625,
#    'deltaSST': 2.848175048828125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 150-155',
#    'avg_sst': 302.45245361328125,
#    'deltaSST': 2.936737060546875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 155-160',
#    'avg_sst': 302.38623046875,
#    'deltaSST': 2.870513916015625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 160-165',
#    'avg_sst': 302.2001953125,
#    'deltaSST': 2.684478759765625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 165-170',
#    'avg_sst': 301.8310546875,
#    'deltaSST': 2.315338134765625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 170-175',
#    'avg_sst': 301.5035400390625,
#    'deltaSST': 1.987823486328125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 175-180',
#    'avg_sst': 301.25030517578125,
#    'deltaSST': 1.734588623046875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 180-185',
#    'avg_sst': 300.925537109375,
#    'deltaSST': 1.409820556640625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 185-190',
#    'avg_sst': 300.5865478515625,
#    'deltaSST': 1.070831298828125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 190-195',
#    'avg_sst': 300.2625427246094,
#    'deltaSST': 0.746826171875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 195-200',
#    'avg_sst': 299.9198303222656,
#    'deltaSST': 0.40411376953125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 200-205',
#    'avg_sst': 299.7969055175781,
#    'deltaSST': 0.28118896484375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 295-300',
#    'avg_sst': 302.8135681152344,
#    'deltaSST': 3.2978515625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 300-305',
#    'avg_sst': 302.5743713378906,
#    'deltaSST': 3.05865478515625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 305-310',
#    'avg_sst': 302.3623962402344,
#    'deltaSST': 2.8466796875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 310-315',
#    'avg_sst': 300.8994445800781,
#    'deltaSST': 1.38372802734375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 315-320',
#    'avg_sst': 300.492919921875,
#    'deltaSST': 0.977203369140625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 320-325',
#    'avg_sst': 300.4005126953125,
#    'deltaSST': 0.884796142578125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 325-330',
#    'avg_sst': 300.26275634765625,
#    'deltaSST': 0.747039794921875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '-5-0, 330-335',
#    'avg_sst': 300.0624084472656,
#    'deltaSST': 0.54669189453125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 0-5',
#    'avg_sst': 300.64251708984375,
#    'deltaSST': 1.126800537109375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 5-10',
#    'avg_sst': 300.61517333984375,
#    'deltaSST': 1.099456787109375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 10-15',
#    'avg_sst': 300.8551940917969,
#    'deltaSST': 1.3394775390625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 35-40',
#    'avg_sst': 300.9583435058594,
#    'deltaSST': 1.442626953125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 40-45',
#    'avg_sst': 299.8538818359375,
#    'deltaSST': 0.338165283203125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 45-50',
#    'avg_sst': 300.09954833984375,
#    'deltaSST': 0.583831787109375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 50-55',
#    'avg_sst': 300.6828918457031,
#    'deltaSST': 1.16717529296875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 55-60',
#    'avg_sst': 301.4727783203125,
#    'deltaSST': 1.957061767578125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 60-65',
#    'avg_sst': 301.7752380371094,
#    'deltaSST': 2.259521484375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 65-70',
#    'avg_sst': 301.8868408203125,
#    'deltaSST': 2.371124267578125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 70-75',
#    'avg_sst': 301.7983703613281,
#    'deltaSST': 2.28265380859375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 75-80',
#    'avg_sst': 301.6134033203125,
#    'deltaSST': 2.097686767578125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 80-85',
#    'avg_sst': 301.572265625,
#    'deltaSST': 2.056549072265625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 85-90',
#    'avg_sst': 301.75579833984375,
#    'deltaSST': 2.240081787109375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 90-95',
#    'avg_sst': 301.9774169921875,
#    'deltaSST': 2.461700439453125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 95-100',
#    'avg_sst': 302.2850036621094,
#    'deltaSST': 2.769287109375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 100-105',
#    'avg_sst': 301.8512878417969,
#    'deltaSST': 2.3355712890625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 105-110',
#    'avg_sst': 301.31976318359375,
#    'deltaSST': 1.804046630859375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 110-115',
#    'avg_sst': 301.5072021484375,
#    'deltaSST': 1.991485595703125,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '0-5, 115-120',
#    'avg_sst': 301.72369384765625,
#    'deltaSST': 2.207977294921875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 120-125',
#    'avg_sst': 301.94464111328125,
#    'deltaSST': 2.428924560546875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 125-130',
#    'avg_sst': 301.92425537109375,
#    'deltaSST': 2.408538818359375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 130-135',
#    'avg_sst': 302.223388671875,
#    'deltaSST': 2.707672119140625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 135-140',
#    'avg_sst': 302.4216613769531,
#    'deltaSST': 2.90594482421875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 140-145',
#    'avg_sst': 302.409423828125,
#    'deltaSST': 2.893707275390625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 145-150',
#    'avg_sst': 302.4110412597656,
#    'deltaSST': 2.89532470703125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 150-155',
#    'avg_sst': 302.3537292480469,
#    'deltaSST': 2.8380126953125,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '0-5, 155-160',
#    'avg_sst': 302.1133117675781,
#    'deltaSST': 2.59759521484375,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '0-5, 160-165',
#    'avg_sst': 301.87677001953125,
#    'deltaSST': 2.361053466796875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 165-170',
#    'avg_sst': 301.5238037109375,
#    'deltaSST': 2.008087158203125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 170-175',
#    'avg_sst': 301.138671875,
#    'deltaSST': 1.622955322265625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 175-180',
#    'avg_sst': 300.8772888183594,
#    'deltaSST': 1.361572265625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 180-185',
#    'avg_sst': 300.522705078125,
#    'deltaSST': 1.006988525390625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 185-190',
#    'avg_sst': 300.3275146484375,
#    'deltaSST': 0.811798095703125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 190-195',
#    'avg_sst': 299.9908142089844,
#    'deltaSST': 0.47509765625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 195-200',
#    'avg_sst': 299.6872253417969,
#    'deltaSST': 0.1715087890625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 280-285',
#    'avg_sst': 299.5562744140625,
#    'deltaSST': 0.040557861328125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 300-305',
#    'avg_sst': 301.27886962890625,
#    'deltaSST': 1.763153076171875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 305-310',
#    'avg_sst': 300.7759094238281,
#    'deltaSST': 1.26019287109375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 310-315',
#    'avg_sst': 300.6932373046875,
#    'deltaSST': 1.177520751953125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 315-320',
#    'avg_sst': 300.593505859375,
#    'deltaSST': 1.077789306640625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 320-325',
#    'avg_sst': 300.4475402832031,
#    'deltaSST': 0.93182373046875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 325-330',
#    'avg_sst': 300.2889709472656,
#    'deltaSST': 0.77325439453125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 330-335',
#    'avg_sst': 300.23193359375,
#    'deltaSST': 0.716217041015625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 335-340',
#    'avg_sst': 300.1856994628906,
#    'deltaSST': 0.66998291015625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 340-345',
#    'avg_sst': 300.3165283203125,
#    'deltaSST': 0.800811767578125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 345-350',
#    'avg_sst': 300.3177490234375,
#    'deltaSST': 0.802032470703125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '0-5, 350-355',
#    'avg_sst': 300.3785705566406,
#    'deltaSST': 0.86285400390625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 0-5',
#    'avg_sst': 300.90728759765625,
#    'deltaSST': 1.391571044921875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 5-10',
#    'avg_sst': 301.23162841796875,
#    'deltaSST': 1.715911865234375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 45-50',
#    'avg_sst': 299.805419921875,
#    'deltaSST': 0.289703369140625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 50-55',
#    'avg_sst': 300.088623046875,
#    'deltaSST': 0.572906494140625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 55-60',
#    'avg_sst': 300.7347717285156,
#    'deltaSST': 1.21905517578125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 60-65',
#    'avg_sst': 301.4148254394531,
#    'deltaSST': 1.89910888671875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 65-70',
#    'avg_sst': 301.7337951660156,
#    'deltaSST': 2.21807861328125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 70-75',
#    'avg_sst': 301.6597900390625,
#    'deltaSST': 2.144073486328125,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '5-10, 75-80',
#    'avg_sst': 301.29443359375,
#    'deltaSST': 1.778717041015625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 80-85',
#    'avg_sst': 301.48236083984375,
#    'deltaSST': 1.966644287109375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 85-90',
#    'avg_sst': 301.5554504394531,
#    'deltaSST': 2.03973388671875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 90-95',
#    'avg_sst': 301.58563232421875,
#    'deltaSST': 2.069915771484375,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '5-10, 95-100',
#    'avg_sst': 301.8662109375,
#    'deltaSST': 2.350494384765625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 100-105',
#    'avg_sst': 301.5586853027344,
#    'deltaSST': 2.04296875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 105-110',
#    'avg_sst': 300.7364501953125,
#    'deltaSST': 1.220733642578125,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '5-10, 110-115',
#    'avg_sst': 300.9721374511719,
#    'deltaSST': 1.4564208984375,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '5-10, 115-120',
#    'avg_sst': 301.37139892578125,
#    'deltaSST': 1.855682373046875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 120-125',
#    'avg_sst': 301.51971435546875,
#    'deltaSST': 2.003997802734375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 125-130',
#    'avg_sst': 301.6753234863281,
#    'deltaSST': 2.15960693359375,
#    'TCs_started': 2,
#    'year': 1971},
#   {'gridbox': '5-10, 130-135',
#    'avg_sst': 301.74822998046875,
#    'deltaSST': 2.232513427734375,
#    'TCs_started': 5,
#    'year': 1971},
#   {'gridbox': '5-10, 135-140',
#    'avg_sst': 302.0962219238281,
#    'deltaSST': 2.58050537109375,
#    'TCs_started': 6,
#    'year': 1971},
#   {'gridbox': '5-10, 140-145',
#    'avg_sst': 302.17913818359375,
#    'deltaSST': 2.663421630859375,
#    'TCs_started': 6,
#    'year': 1971},
#   {'gridbox': '5-10, 145-150',
#    'avg_sst': 302.1019592285156,
#    'deltaSST': 2.58624267578125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 150-155',
#    'avg_sst': 302.1044006347656,
#    'deltaSST': 2.58868408203125,
#    'TCs_started': 3,
#    'year': 1971},
#   {'gridbox': '5-10, 155-160',
#    'avg_sst': 302.0093688964844,
#    'deltaSST': 2.49365234375,
#    'TCs_started': 2,
#    'year': 1971},
#   {'gridbox': '5-10, 160-165',
#    'avg_sst': 301.9840087890625,
#    'deltaSST': 2.468292236328125,
#    'TCs_started': 2,
#    'year': 1971},
#   {'gridbox': '5-10, 165-170',
#    'avg_sst': 301.75927734375,
#    'deltaSST': 2.243560791015625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 170-175',
#    'avg_sst': 301.3738098144531,
#    'deltaSST': 1.85809326171875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 175-180',
#    'avg_sst': 301.2115783691406,
#    'deltaSST': 1.69586181640625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 180-185',
#    'avg_sst': 301.04974365234375,
#    'deltaSST': 1.534027099609375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 185-190',
#    'avg_sst': 300.79205322265625,
#    'deltaSST': 1.276336669921875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 190-195',
#    'avg_sst': 300.6601867675781,
#    'deltaSST': 1.14447021484375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 195-200',
#    'avg_sst': 300.5148010253906,
#    'deltaSST': 0.99908447265625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 200-205',
#    'avg_sst': 300.2691955566406,
#    'deltaSST': 0.75347900390625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 205-210',
#    'avg_sst': 300.09423828125,
#    'deltaSST': 0.578521728515625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 210-215',
#    'avg_sst': 300.0027770996094,
#    'deltaSST': 0.487060546875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 215-220',
#    'avg_sst': 299.75531005859375,
#    'deltaSST': 0.239593505859375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 220-225',
#    'avg_sst': 299.6830139160156,
#    'deltaSST': 0.16729736328125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 225-230',
#    'avg_sst': 299.6759948730469,
#    'deltaSST': 0.1602783203125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 230-235',
#    'avg_sst': 299.8163146972656,
#    'deltaSST': 0.30059814453125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 235-240',
#    'avg_sst': 299.8742980957031,
#    'deltaSST': 0.35858154296875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 240-245',
#    'avg_sst': 300.0010070800781,
#    'deltaSST': 0.48529052734375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 245-250',
#    'avg_sst': 300.1141662597656,
#    'deltaSST': 0.59844970703125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 250-255',
#    'avg_sst': 300.3280944824219,
#    'deltaSST': 0.8123779296875,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '5-10, 255-260',
#    'avg_sst': 300.2893371582031,
#    'deltaSST': 0.77362060546875,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '5-10, 260-265',
#    'avg_sst': 300.23541259765625,
#    'deltaSST': 0.719696044921875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 265-270',
#    'avg_sst': 300.03021240234375,
#    'deltaSST': 0.514495849609375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 270-275',
#    'avg_sst': 300.18768310546875,
#    'deltaSST': 0.671966552734375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 275-280',
#    'avg_sst': 300.5120544433594,
#    'deltaSST': 0.996337890625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 280-285',
#    'avg_sst': 300.3353576660156,
#    'deltaSST': 0.81964111328125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 285-290',
#    'avg_sst': 302.7667236328125,
#    'deltaSST': 3.251007080078125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 295-300',
#    'avg_sst': 300.3806457519531,
#    'deltaSST': 0.86492919921875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 300-305',
#    'avg_sst': 300.5569763183594,
#    'deltaSST': 1.041259765625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 305-310',
#    'avg_sst': 300.6650695800781,
#    'deltaSST': 1.14935302734375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 310-315',
#    'avg_sst': 300.609375,
#    'deltaSST': 1.093658447265625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 315-320',
#    'avg_sst': 300.2695007324219,
#    'deltaSST': 0.7537841796875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 320-325',
#    'avg_sst': 300.05523681640625,
#    'deltaSST': 0.539520263671875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 325-330',
#    'avg_sst': 300.0283508300781,
#    'deltaSST': 0.51263427734375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 330-335',
#    'avg_sst': 299.9316101074219,
#    'deltaSST': 0.4158935546875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 335-340',
#    'avg_sst': 300.044921875,
#    'deltaSST': 0.529205322265625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 340-345',
#    'avg_sst': 300.5671691894531,
#    'deltaSST': 1.05145263671875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 345-350',
#    'avg_sst': 300.90350341796875,
#    'deltaSST': 1.387786865234375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '5-10, 350-355',
#    'avg_sst': 300.7461242675781,
#    'deltaSST': 1.23040771484375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 40-45',
#    'avg_sst': 301.7301330566406,
#    'deltaSST': 2.21441650390625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 45-50',
#    'avg_sst': 301.1019592285156,
#    'deltaSST': 1.58624267578125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 50-55',
#    'avg_sst': 299.8034973144531,
#    'deltaSST': 0.28778076171875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 55-60',
#    'avg_sst': 299.94384765625,
#    'deltaSST': 0.428131103515625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 60-65',
#    'avg_sst': 300.5413513183594,
#    'deltaSST': 1.025634765625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 65-70',
#    'avg_sst': 301.24737548828125,
#    'deltaSST': 1.731658935546875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 70-75',
#    'avg_sst': 301.51348876953125,
#    'deltaSST': 1.997772216796875,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '10-15, 75-80',
#    'avg_sst': 301.328369140625,
#    'deltaSST': 1.812652587890625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 80-85',
#    'avg_sst': 301.5821838378906,
#    'deltaSST': 2.06646728515625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 85-90',
#    'avg_sst': 301.41729736328125,
#    'deltaSST': 1.901580810546875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 90-95',
#    'avg_sst': 301.48486328125,
#    'deltaSST': 1.969146728515625,
#    'TCs_started': 2,
#    'year': 1971},
#   {'gridbox': '10-15, 95-100',
#    'avg_sst': 301.4695129394531,
#    'deltaSST': 1.95379638671875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 100-105',
#    'avg_sst': 301.68017578125,
#    'deltaSST': 2.164459228515625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 105-110',
#    'avg_sst': 300.1605224609375,
#    'deltaSST': 0.644805908203125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 110-115',
#    'avg_sst': 300.525146484375,
#    'deltaSST': 1.009429931640625,
#    'TCs_started': 3,
#    'year': 1971},
#   {'gridbox': '10-15, 115-120',
#    'avg_sst': 301.0857849121094,
#    'deltaSST': 1.570068359375,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '10-15, 120-125',
#    'avg_sst': 301.0713195800781,
#    'deltaSST': 1.55560302734375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 125-130',
#    'avg_sst': 301.5208435058594,
#    'deltaSST': 2.005126953125,
#    'TCs_started': 2,
#    'year': 1971},
#   {'gridbox': '10-15, 130-135',
#    'avg_sst': 301.6895446777344,
#    'deltaSST': 2.173828125,
#    'TCs_started': 4,
#    'year': 1971},
#   {'gridbox': '10-15, 135-140',
#    'avg_sst': 301.8995666503906,
#    'deltaSST': 2.38385009765625,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '10-15, 140-145',
#    'avg_sst': 301.83453369140625,
#    'deltaSST': 2.318817138671875,
#    'TCs_started': 3,
#    'year': 1971},
#   {'gridbox': '10-15, 145-150',
#    'avg_sst': 301.7786865234375,
#    'deltaSST': 2.262969970703125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 150-155',
#    'avg_sst': 301.6637268066406,
#    'deltaSST': 2.14801025390625,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '10-15, 155-160',
#    'avg_sst': 301.5082702636719,
#    'deltaSST': 1.9925537109375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 160-165',
#    'avg_sst': 301.3375244140625,
#    'deltaSST': 1.821807861328125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 165-170',
#    'avg_sst': 301.0946044921875,
#    'deltaSST': 1.578887939453125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 170-175',
#    'avg_sst': 300.8689270019531,
#    'deltaSST': 1.35321044921875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 175-180',
#    'avg_sst': 300.6698303222656,
#    'deltaSST': 1.15411376953125,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '10-15, 180-185',
#    'avg_sst': 300.3968811035156,
#    'deltaSST': 0.88116455078125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 185-190',
#    'avg_sst': 300.1037292480469,
#    'deltaSST': 0.5880126953125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 190-195',
#    'avg_sst': 299.7700500488281,
#    'deltaSST': 0.25433349609375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 195-200',
#    'avg_sst': 299.65234375,
#    'deltaSST': 0.136627197265625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 240-245',
#    'avg_sst': 299.85687255859375,
#    'deltaSST': 0.341156005859375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 245-250',
#    'avg_sst': 300.32403564453125,
#    'deltaSST': 0.808319091796875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 250-255',
#    'avg_sst': 300.8677062988281,
#    'deltaSST': 1.35198974609375,
#    'TCs_started': 4,
#    'year': 1971},
#   {'gridbox': '10-15, 255-260',
#    'avg_sst': 301.1783447265625,
#    'deltaSST': 1.662628173828125,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '10-15, 260-265',
#    'avg_sst': 300.95904541015625,
#    'deltaSST': 1.443328857421875,
#    'TCs_started': 4,
#    'year': 1971},
#   {'gridbox': '10-15, 265-270',
#    'avg_sst': 301.001220703125,
#    'deltaSST': 1.485504150390625,
#    'TCs_started': 2,
#    'year': 1971},
#   {'gridbox': '10-15, 270-275',
#    'avg_sst': 300.3565368652344,
#    'deltaSST': 0.8408203125,
#    'TCs_started': 2,
#    'year': 1971},
#   {'gridbox': '10-15, 275-280',
#    'avg_sst': 300.64703369140625,
#    'deltaSST': 1.131317138671875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 280-285',
#    'avg_sst': 300.5056457519531,
#    'deltaSST': 0.98992919921875,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '10-15, 285-290',
#    'avg_sst': 300.062744140625,
#    'deltaSST': 0.547027587890625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 290-295',
#    'avg_sst': 300.1695251464844,
#    'deltaSST': 0.65380859375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 295-300',
#    'avg_sst': 300.3724365234375,
#    'deltaSST': 0.856719970703125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '10-15, 300-305',
#    'avg_sst': 300.3798828125,
#    'deltaSST': 0.864166259765625,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '10-15, 305-310',
#    'avg_sst': 300.07403564453125,
#    'deltaSST': 0.558319091796875,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '10-15, 310-315',
#    'avg_sst': 299.6861572265625,
#    'deltaSST': 0.170440673828125,
#    'TCs_started': 2,
#    'year': 1971},
#   {'gridbox': '10-15, 345-350',
#    'avg_sst': 300.1239013671875,
#    'deltaSST': 0.608184814453125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 35-40',
#    'avg_sst': 302.37738037109375,
#    'deltaSST': 2.861663818359375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 40-45',
#    'avg_sst': 302.55023193359375,
#    'deltaSST': 3.034515380859375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 60-65',
#    'avg_sst': 300.1683349609375,
#    'deltaSST': 0.652618408203125,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '15-20, 65-70',
#    'avg_sst': 300.71075439453125,
#    'deltaSST': 1.195037841796875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 70-75',
#    'avg_sst': 301.0879211425781,
#    'deltaSST': 1.57220458984375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 75-80',
#    'avg_sst': 301.40716552734375,
#    'deltaSST': 1.891448974609375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 80-85',
#    'avg_sst': 301.4678039550781,
#    'deltaSST': 1.95208740234375,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '15-20, 85-90',
#    'avg_sst': 301.218994140625,
#    'deltaSST': 1.703277587890625,
#    'TCs_started': 5,
#    'year': 1971},
#   {'gridbox': '15-20, 90-95',
#    'avg_sst': 301.13861083984375,
#    'deltaSST': 1.622894287109375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 95-100',
#    'avg_sst': 301.0091552734375,
#    'deltaSST': 1.493438720703125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 110-115',
#    'avg_sst': 299.5800476074219,
#    'deltaSST': 0.0643310546875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 115-120',
#    'avg_sst': 300.1996154785156,
#    'deltaSST': 0.68389892578125,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '15-20, 120-125',
#    'avg_sst': 300.7137756347656,
#    'deltaSST': 1.19805908203125,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '15-20, 125-130',
#    'avg_sst': 300.7422790527344,
#    'deltaSST': 1.2265625,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '15-20, 130-135',
#    'avg_sst': 301.0191650390625,
#    'deltaSST': 1.503448486328125,
#    'TCs_started': 3,
#    'year': 1971},
#   {'gridbox': '15-20, 135-140',
#    'avg_sst': 301.3276672363281,
#    'deltaSST': 1.81195068359375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 140-145',
#    'avg_sst': 301.3969421386719,
#    'deltaSST': 1.8812255859375,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '15-20, 145-150',
#    'avg_sst': 301.45782470703125,
#    'deltaSST': 1.942108154296875,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '15-20, 150-155',
#    'avg_sst': 301.528076171875,
#    'deltaSST': 2.012359619140625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 155-160',
#    'avg_sst': 301.42987060546875,
#    'deltaSST': 1.914154052734375,
#    'TCs_started': 2,
#    'year': 1971},
#   {'gridbox': '15-20, 160-165',
#    'avg_sst': 301.0506286621094,
#    'deltaSST': 1.534912109375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 165-170',
#    'avg_sst': 300.6937255859375,
#    'deltaSST': 1.178009033203125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 170-175',
#    'avg_sst': 300.37127685546875,
#    'deltaSST': 0.855560302734375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 175-180',
#    'avg_sst': 300.12701416015625,
#    'deltaSST': 0.611297607421875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 180-185',
#    'avg_sst': 299.82733154296875,
#    'deltaSST': 0.311614990234375,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 185-190',
#    'avg_sst': 299.5920715332031,
#    'deltaSST': 0.07635498046875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 250-255',
#    'avg_sst': 299.77838134765625,
#    'deltaSST': 0.262664794921875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 255-260',
#    'avg_sst': 300.9346008300781,
#    'deltaSST': 1.41888427734375,
#    'TCs_started': 2,
#    'year': 1971},
#   {'gridbox': '15-20, 260-265',
#    'avg_sst': 300.9296569824219,
#    'deltaSST': 1.4139404296875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 265-270',
#    'avg_sst': 300.1822814941406,
#    'deltaSST': 0.66656494140625,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 270-275',
#    'avg_sst': 300.9234619140625,
#    'deltaSST': 1.407745361328125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 275-280',
#    'avg_sst': 300.7319641113281,
#    'deltaSST': 1.21624755859375,
#    'TCs_started': 1,
#    'year': 1971},
#   {'gridbox': '15-20, 280-285',
#    'avg_sst': 300.79522705078125,
#    'deltaSST': 1.279510498046875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 285-290',
#    'avg_sst': 300.56256103515625,
#    'deltaSST': 1.046844482421875,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 290-295',
#    'avg_sst': 300.4563903808594,
#    'deltaSST': 0.940673828125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 295-300',
#    'avg_sst': 300.3533935546875,
#    'deltaSST': 0.837677001953125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 300-305',
#    'avg_sst': 300.0619201660156,
#    'deltaSST': 0.54620361328125,
#    'TCs_started': 0,
#    'year': 1971},
#   {'gridbox': '15-20, 305-310',
#    'avg_sst': 299.54791259765625,
#    'deltaSST': 0.032196044921875,
#    'TCs_started': 0,
#    'year': 1971}],
#  1972: [{'gridbox': '-20--15, 40-45',
#    'avg_sst': 300.3177185058594,
#    'deltaSST': 0.424072265625,
#    'TCs_started': 0,
#    'year': 1972},
#   {'gridbox': '-20--15, 45-50',
#    'avg_sst': 299.9858093261719,
#    'deltaSST': 0.0921630859375,
#    'TCs_started': 0,
# ...
#    'year': 2021},
#   {'gridbox': '5-10, 180-185',
#    'avg_sst': 301.5265808105469,
#    'deltaSST': 1.417144775390625,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 185-190',
#    'avg_sst': 301.36468505859375,
#    'deltaSST': 1.2552490234375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 190-195',
#    'avg_sst': 301.1967468261719,
#    'deltaSST': 1.087310791015625,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '5-10, 195-200',
#    'avg_sst': 301.0339050292969,
#    'deltaSST': 0.924468994140625,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 200-205',
#    'avg_sst': 300.899169921875,
#    'deltaSST': 0.78973388671875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 205-210',
#    'avg_sst': 300.7572021484375,
#    'deltaSST': 0.64776611328125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 210-215',
#    'avg_sst': 300.5560302734375,
#    'deltaSST': 0.44659423828125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 215-220',
#    'avg_sst': 300.482421875,
#    'deltaSST': 0.37298583984375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 220-225',
#    'avg_sst': 300.3981628417969,
#    'deltaSST': 0.288726806640625,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 225-230',
#    'avg_sst': 300.35870361328125,
#    'deltaSST': 0.249267578125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 230-235',
#    'avg_sst': 300.402587890625,
#    'deltaSST': 0.29315185546875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 235-240',
#    'avg_sst': 300.4610290527344,
#    'deltaSST': 0.351593017578125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 240-245',
#    'avg_sst': 300.5499572753906,
#    'deltaSST': 0.440521240234375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 245-250',
#    'avg_sst': 300.75640869140625,
#    'deltaSST': 0.64697265625,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 250-255',
#    'avg_sst': 300.89044189453125,
#    'deltaSST': 0.781005859375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 255-260',
#    'avg_sst': 300.90374755859375,
#    'deltaSST': 0.7943115234375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 260-265',
#    'avg_sst': 300.8633117675781,
#    'deltaSST': 0.753875732421875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 265-270',
#    'avg_sst': 300.7540283203125,
#    'deltaSST': 0.64459228515625,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 270-275',
#    'avg_sst': 300.7596740722656,
#    'deltaSST': 0.650238037109375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 275-280',
#    'avg_sst': 301.3442687988281,
#    'deltaSST': 1.234832763671875,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '5-10, 280-285',
#    'avg_sst': 301.1210632324219,
#    'deltaSST': 1.011627197265625,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 285-290',
#    'avg_sst': 303.7671813964844,
#    'deltaSST': 3.657745361328125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 295-300',
#    'avg_sst': 301.2126159667969,
#    'deltaSST': 1.103179931640625,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 300-305',
#    'avg_sst': 301.21685791015625,
#    'deltaSST': 1.107421875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 305-310',
#    'avg_sst': 301.26153564453125,
#    'deltaSST': 1.152099609375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 310-315',
#    'avg_sst': 301.1231689453125,
#    'deltaSST': 1.01373291015625,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 315-320',
#    'avg_sst': 301.0061950683594,
#    'deltaSST': 0.896759033203125,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '5-10, 320-325',
#    'avg_sst': 300.8347473144531,
#    'deltaSST': 0.725311279296875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 325-330',
#    'avg_sst': 300.7723083496094,
#    'deltaSST': 0.662872314453125,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '5-10, 330-335',
#    'avg_sst': 300.73797607421875,
#    'deltaSST': 0.6285400390625,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 335-340',
#    'avg_sst': 300.9346618652344,
#    'deltaSST': 0.825225830078125,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '5-10, 340-345',
#    'avg_sst': 301.4188537597656,
#    'deltaSST': 1.309417724609375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 345-350',
#    'avg_sst': 301.6952209472656,
#    'deltaSST': 1.585784912109375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '5-10, 350-355',
#    'avg_sst': 301.21417236328125,
#    'deltaSST': 1.104736328125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 40-45',
#    'avg_sst': 301.9598388671875,
#    'deltaSST': 1.85040283203125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 45-50',
#    'avg_sst': 301.6175537109375,
#    'deltaSST': 1.50811767578125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 60-65',
#    'avg_sst': 300.7869873046875,
#    'deltaSST': 0.67755126953125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 65-70',
#    'avg_sst': 301.589599609375,
#    'deltaSST': 1.48016357421875,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '10-15, 70-75',
#    'avg_sst': 302.1211242675781,
#    'deltaSST': 2.011688232421875,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '10-15, 75-80',
#    'avg_sst': 301.9692687988281,
#    'deltaSST': 1.859832763671875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 80-85',
#    'avg_sst': 302.182373046875,
#    'deltaSST': 2.07293701171875,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '10-15, 85-90',
#    'avg_sst': 302.22564697265625,
#    'deltaSST': 2.1162109375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 90-95',
#    'avg_sst': 302.247802734375,
#    'deltaSST': 2.13836669921875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 95-100',
#    'avg_sst': 302.2657775878906,
#    'deltaSST': 2.156341552734375,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '10-15, 100-105',
#    'avg_sst': 302.393798828125,
#    'deltaSST': 2.28436279296875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 105-110',
#    'avg_sst': 300.815673828125,
#    'deltaSST': 0.70623779296875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 110-115',
#    'avg_sst': 301.4739990234375,
#    'deltaSST': 1.36456298828125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 115-120',
#    'avg_sst': 302.2336730957031,
#    'deltaSST': 2.124237060546875,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '10-15, 120-125',
#    'avg_sst': 302.1142272949219,
#    'deltaSST': 2.004791259765625,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '10-15, 125-130',
#    'avg_sst': 302.5032653808594,
#    'deltaSST': 2.393829345703125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 130-135',
#    'avg_sst': 302.5262145996094,
#    'deltaSST': 2.416778564453125,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '10-15, 135-140',
#    'avg_sst': 302.48980712890625,
#    'deltaSST': 2.38037109375,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '10-15, 140-145',
#    'avg_sst': 302.40673828125,
#    'deltaSST': 2.29730224609375,
#    'TCs_started': 2,
#    'year': 2021},
#   {'gridbox': '10-15, 145-150',
#    'avg_sst': 302.3116149902344,
#    'deltaSST': 2.202178955078125,
#    'TCs_started': 3,
#    'year': 2021},
#   {'gridbox': '10-15, 150-155',
#    'avg_sst': 302.1736145019531,
#    'deltaSST': 2.064178466796875,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '10-15, 155-160',
#    'avg_sst': 301.98980712890625,
#    'deltaSST': 1.88037109375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 160-165',
#    'avg_sst': 301.7308044433594,
#    'deltaSST': 1.621368408203125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 165-170',
#    'avg_sst': 301.46124267578125,
#    'deltaSST': 1.351806640625,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 170-175',
#    'avg_sst': 301.1929931640625,
#    'deltaSST': 1.08355712890625,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 175-180',
#    'avg_sst': 300.934326171875,
#    'deltaSST': 0.82489013671875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 180-185',
#    'avg_sst': 300.7101135253906,
#    'deltaSST': 0.600677490234375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 185-190',
#    'avg_sst': 300.4812927246094,
#    'deltaSST': 0.371856689453125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 190-195',
#    'avg_sst': 300.2147521972656,
#    'deltaSST': 0.105316162109375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 240-245',
#    'avg_sst': 300.4610900878906,
#    'deltaSST': 0.351654052734375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 245-250',
#    'avg_sst': 301.0106201171875,
#    'deltaSST': 0.90118408203125,
#    'TCs_started': 4,
#    'year': 2021},
#   {'gridbox': '10-15, 250-255',
#    'avg_sst': 301.6114501953125,
#    'deltaSST': 1.50201416015625,
#    'TCs_started': 2,
#    'year': 2021},
#   {'gridbox': '10-15, 255-260',
#    'avg_sst': 301.9352111816406,
#    'deltaSST': 1.825775146484375,
#    'TCs_started': 4,
#    'year': 2021},
#   {'gridbox': '10-15, 260-265',
#    'avg_sst': 301.7823486328125,
#    'deltaSST': 1.67291259765625,
#    'TCs_started': 3,
#    'year': 2021},
#   {'gridbox': '10-15, 265-270',
#    'avg_sst': 301.91973876953125,
#    'deltaSST': 1.810302734375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 270-275',
#    'avg_sst': 301.16650390625,
#    'deltaSST': 1.05706787109375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 275-280',
#    'avg_sst': 301.4122009277344,
#    'deltaSST': 1.302764892578125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 280-285',
#    'avg_sst': 301.17913818359375,
#    'deltaSST': 1.0697021484375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 285-290',
#    'avg_sst': 300.656982421875,
#    'deltaSST': 0.54754638671875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 290-295',
#    'avg_sst': 300.770751953125,
#    'deltaSST': 0.66131591796875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 295-300',
#    'avg_sst': 300.8721008300781,
#    'deltaSST': 0.762664794921875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 300-305',
#    'avg_sst': 300.993896484375,
#    'deltaSST': 0.88446044921875,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '10-15, 305-310',
#    'avg_sst': 300.6384582519531,
#    'deltaSST': 0.529022216796875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '10-15, 310-315',
#    'avg_sst': 300.1822509765625,
#    'deltaSST': 0.07281494140625,
#    'TCs_started': 2,
#    'year': 2021},
#   {'gridbox': '10-15, 345-350',
#    'avg_sst': 301.1607360839844,
#    'deltaSST': 1.051300048828125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 35-40',
#    'avg_sst': 302.80706787109375,
#    'deltaSST': 2.6976318359375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 40-45',
#    'avg_sst': 302.9798278808594,
#    'deltaSST': 2.870391845703125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 60-65',
#    'avg_sst': 300.41546630859375,
#    'deltaSST': 0.3060302734375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 65-70',
#    'avg_sst': 301.2137756347656,
#    'deltaSST': 1.104339599609375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 70-75',
#    'avg_sst': 301.8023376464844,
#    'deltaSST': 1.692901611328125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 75-80',
#    'avg_sst': 301.721923828125,
#    'deltaSST': 1.61248779296875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 80-85',
#    'avg_sst': 301.9613342285156,
#    'deltaSST': 1.851898193359375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 85-90',
#    'avg_sst': 301.8631591796875,
#    'deltaSST': 1.75372314453125,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '15-20, 90-95',
#    'avg_sst': 301.91015625,
#    'deltaSST': 1.80072021484375,
#    'TCs_started': 2,
#    'year': 2021},
#   {'gridbox': '15-20, 95-100',
#    'avg_sst': 302.1683044433594,
#    'deltaSST': 2.058868408203125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 105-110',
#    'avg_sst': 300.1152038574219,
#    'deltaSST': 0.005767822265625,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 110-115',
#    'avg_sst': 300.8226013183594,
#    'deltaSST': 0.713165283203125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 115-120',
#    'avg_sst': 301.4292297363281,
#    'deltaSST': 1.319793701171875,
#    'TCs_started': 2,
#    'year': 2021},
#   {'gridbox': '15-20, 120-125',
#    'avg_sst': 301.7998352050781,
#    'deltaSST': 1.690399169921875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 125-130',
#    'avg_sst': 301.8340148925781,
#    'deltaSST': 1.724578857421875,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '15-20, 130-135',
#    'avg_sst': 301.940185546875,
#    'deltaSST': 1.83074951171875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 135-140',
#    'avg_sst': 302.06243896484375,
#    'deltaSST': 1.9530029296875,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '15-20, 140-145',
#    'avg_sst': 302.1720886230469,
#    'deltaSST': 2.062652587890625,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 145-150',
#    'avg_sst': 302.11712646484375,
#    'deltaSST': 2.0076904296875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 150-155',
#    'avg_sst': 301.9820251464844,
#    'deltaSST': 1.872589111328125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 155-160',
#    'avg_sst': 301.8030700683594,
#    'deltaSST': 1.693634033203125,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '15-20, 160-165',
#    'avg_sst': 301.56781005859375,
#    'deltaSST': 1.4583740234375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 165-170',
#    'avg_sst': 301.2477111816406,
#    'deltaSST': 1.138275146484375,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '15-20, 170-175',
#    'avg_sst': 300.9474792480469,
#    'deltaSST': 0.838043212890625,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 175-180',
#    'avg_sst': 300.6695861816406,
#    'deltaSST': 0.560150146484375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 180-185',
#    'avg_sst': 300.376708984375,
#    'deltaSST': 0.26727294921875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 185-190',
#    'avg_sst': 300.1309509277344,
#    'deltaSST': 0.021514892578125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 250-255',
#    'avg_sst': 300.6878662109375,
#    'deltaSST': 0.57843017578125,
#    'TCs_started': 3,
#    'year': 2021},
#   {'gridbox': '15-20, 255-260',
#    'avg_sst': 301.9080810546875,
#    'deltaSST': 1.79864501953125,
#    'TCs_started': 2,
#    'year': 2021},
#   {'gridbox': '15-20, 260-265',
#    'avg_sst': 301.757080078125,
#    'deltaSST': 1.64764404296875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 265-270',
#    'avg_sst': 301.1262512207031,
#    'deltaSST': 1.016815185546875,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 270-275',
#    'avg_sst': 301.51202392578125,
#    'deltaSST': 1.402587890625,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 275-280',
#    'avg_sst': 301.5169677734375,
#    'deltaSST': 1.40753173828125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 280-285',
#    'avg_sst': 301.4539489746094,
#    'deltaSST': 1.344512939453125,
#    'TCs_started': 1,
#    'year': 2021},
#   {'gridbox': '15-20, 285-290',
#    'avg_sst': 301.20941162109375,
#    'deltaSST': 1.0999755859375,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 290-295',
#    'avg_sst': 301.0589294433594,
#    'deltaSST': 0.949493408203125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 295-300',
#    'avg_sst': 300.84869384765625,
#    'deltaSST': 0.7392578125,
#    'TCs_started': 0,
#    'year': 2021},
#   {'gridbox': '15-20, 300-305',
#    'avg_sst': 300.4335632324219,
#    'deltaSST': 0.324127197265625,
#    'TCs_started': 0,
#    'year': 2021}]}

# %% [markdown]
# <h2 style="font-size:28px; font-weight:bold;">Analyzing TC Genesis Frequency Across SST Bins</h2>

# %%
# Defining SST bins from 26°C to 32°C with 0.5°C increments, converting to Kelvin
sst_bins = np.arange(25.5, 31.5, 0.2) + 273.15
# Calculating midpoints of SST bins for plotting, converting back to Celsius
sst_midpoints = (sst_bins[:-1] + sst_bins[1:]) / 2 - 273.15  

# Initializing a list to hold the sum of TC starts for each SST bin
tc_starts_per_bin = np.zeros(len(sst_midpoints))

# Processing data for each year
for year, items in result.items():
    for item in items:
        avg_sst = item['avg_sst']  # The average SST is in Kelvin
        tc_starts = item['TCs_started']
        
        # Finding the bin index for the current avg_sst
        bin_index = np.digitize(avg_sst, sst_bins) - 1  
        # Adding TC starts to the corresponding SST bin, if within range
        if 0 <= bin_index < len(tc_starts_per_bin):
            tc_starts_per_bin[bin_index] += tc_starts

# Preparing arrays for plotting
sst_midpoints_array = np.array(sst_midpoints)
tc_starts_per_bin_array = np.array(tc_starts_per_bin)

# Customizing tick labels for SST in Celsius
custom_ticks = np.arange(25, 31.6, 0.5)
custom_labels = [f"{tick:.1f}" for tick in custom_ticks]

# Plotting TC starts vs. SST bins
plt.figure(figsize=(10, 6))
plt.plot(sst_midpoints_array, tc_starts_per_bin_array, color='royalblue', linewidth=2, markersize=6)
plt.title('TC Starts vs. SST Bins')
plt.xlabel('SST (°C)')
plt.ylabel('Number of TC Starts')
plt.xticks(custom_ticks, custom_labels, rotation=45)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()  # Adjusting the layout for a better fit
plt.show()

# %% [markdown]
# <h2 style="font-size:24px; font-weight:bold;">Plot examination</h2>
#
# <div style="font-size:18px;">
# <p>The plot presents a pronounced peak in the number of TCs starts within the SST range of 27-29°C, reinforcing the concept that there's an optimal SST window for cyclone genesis. As SSTs rise above 26°C, TC starts increase sharply, reach a maximum in the 27-29°C range, and then decline significantly beyond this range. The drop-off in TC starts at higher SSTs may imply other environmental factors come into play that inhibit cyclone formation despite the availability of warm waters.
# </p>
# </div>

# %%
# Assuming deltaSST values are relatively small, define a reasonable range and bin size for deltaSST
delta_sst_bins = np.arange(-1, 4.1, 0.2)  # Adjusted range and bin size based on your data
# Calculating midpoints of delta SST bins for plotting
delta_sst_midpoints = (delta_sst_bins[:-1] + delta_sst_bins[1:]) / 2

# Initializing a list to hold the sum of TC starts for each delta SST bin
tc_starts_per_delta_bin = np.zeros(len(delta_sst_midpoints))

# Processing data for each year
for year, items in result.items():
    for item in items:
        delta_sst = item['deltaSST']  # The delta SST for each grid box
        tc_starts = item['TCs_started']
        
        # Finding the bin index for the current delta_sst
        bin_index = np.digitize(delta_sst, delta_sst_bins) - 1
        # Adding TC starts to the corresponding delta SST bin, if within range
        if 0 <= bin_index < len(tc_starts_per_delta_bin):
            tc_starts_per_delta_bin[bin_index] += tc_starts

# Preparing arrays for plotting
delta_sst_midpoints_array = np.array(delta_sst_midpoints)
tc_starts_per_delta_bin_array = np.array(tc_starts_per_delta_bin)

# Plotting TC starts vs. delta SST bins as a line plot
plt.figure(figsize=(10, 6))
plt.plot(delta_sst_midpoints_array, tc_starts_per_delta_bin_array, linestyle='-', color='royalblue', linewidth=2, markersize=6)
plt.title('TC Starts vs. Delta SST Bins')
plt.xlabel('Tropical mean for the year - Average SST of the cell (°C)')
plt.ylabel('Number of TC Starts')
plt.xticks(np.arange(-1, 4.5, 0.5), [f"{x:.1f}" for x in np.arange(-1, 4.5, 0.5)], rotation=45)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()  # Adjusting the layout for a better fit
plt.show()

# %%
dsst = []  
sst = []
tc = []  
for year in result:
    for data in result[year]:  
        dsst.append(data['deltaSST'])
        sst.append(data['avg_sst'])  
        tc.append(data['TCs_started'])  


dsst = np.array(dsst)
tc = np.array(tc)
counts = [0,1, 2, 3, 4, 5]
plt.figure(figsize=(10, 6))

for count in counts:
    ii = np.nonzero(tc == count)[0]  
    dsst_at_this_count = dsst[ii]  
    cpdf = fastkde.pdf(dsst_at_this_count)  
    #plt.plot(cpdf, label=f'{count}')  
    cpdf.plot(label = f"{count}")

plt.title('PDF of deltaSST for Different TC Counts')
plt.xlabel('$\Delta$SST')
plt.ylabel('Pdf(deltaSST)')
plt.legend()  
plt.grid(True)  
plt.show()

# %% [markdown]
# $$ P(i | \Delta \text{SST}) = \frac{P(\Delta \text{SST} | i)}{P(i)}$$
#
# $$P(i) = \frac{N_i}{\sum N_i}$$
#
# Here, $i$ is the number of TCs counted in a grid region, and $N_i$ is the number of observations with $i$ TCs in a cell.  In the code below, this is just `len(ii)`

# %%
dsst = []  
sst = []
tc = []  
for year in result:
    for data in result[year]:  
        dsst.append(data['deltaSST'])
        sst.append(data['avg_sst'])  
        tc.append(data['TCs_started'])  

dsst = np.array(dsst)
tc = np.array(tc)
counts = [0,1, 2, 3, 4, 5]

# calculate the marginal distrbution of dsst
P_dsst, sst_axis = fastkde.pdf(np.asarray(dsst), use_xarray = False, num_points= 1025)

# initialize P_dsst_i to have the correct shape
P_dsst_i = np.empty([len(counts), len(sst_axis)])


for count in counts:
    i = np.nonzero(tc == count)[0]  
    dsst_i = dsst[i]  
    # calculate P(dsst | i) at the same points that P(dsst) is calculate
    P_dsst_i[count, :], _ = fastkde.pdf(dsst_i, axes = [sst_axis], use_xarray = False) 

    P_i = len(np.nonzero(tc == count)[0]) / len(tc)

    P_dsst_i[count, :] = P_dsst_i[count, :] * P_i


# calculate the conditional of i | dsst
P_i_dsst = P_dsst_i/P_dsst

# convert to xarray
P_i_dsst = xr.DataArray(P_i_dsst, dims = ("i", "dsst"), coords = dict(i = counts, dsst = sst_axis))

# subset from 0 to 3
P_i_dsst = P_i_dsst.sel(dsst = slice(0,3))

# calculate the sst probability amplification factor (risk ratio)
P_dsst_0 = P_i_dsst.sel(dsst = 0, method = 'nearest')

cond_prob_amp = P_i_dsst / P_dsst_0

plt.figure(figsize=(8, 6))
cond_prob_amp.plot(cmap='viridis')
plt.xlabel('$\Delta$SST')
plt.ylabel('Count of Tropical Cyclones (i)')
plt.title('Conditional Probability of Tropical Cyclones given $\Delta$SST')
plt.show()
# Out:
# /var/folders/1z/84y74_xs347cxhm6360l4xvm0000gn/T/ipykernel_1017/3445233014.py:33: RuntimeWarning: divide by zero encountered in divide
#   P_i_dsst = P_dsst_i/P_dsst
# /var/folders/1z/84y74_xs347cxhm6360l4xvm0000gn/T/ipykernel_1017/3445233014.py:33: RuntimeWarning: invalid value encountered in divide
#   P_i_dsst = P_dsst_i/P_dsst
